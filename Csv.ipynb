# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
df = pd.read_csv('IPL.csv' , use_cols=['match_id','date','match_type',]
# Out:
# C:\Users\pmax8\AppData\Local\Temp\ipykernel_13872\3654700135.py:2: DtypeWarning: Columns (0: review_batter, 1: team_reviewed, 2: review_decision, 3: umpire, 4: season, 5: superover_winner, 6: result_type, 7: method, 8: event_match_no) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('IPL.csv')

# %%
df
# Out:
#         match_id        date match_type             event_name  innings  \
# 0         335982  2008-04-18        T20  Indian Premier League        1
# 1         335982  2008-04-18        T20  Indian Premier League        1
# 2         335982  2008-04-18        T20  Indian Premier League        1
# 3         335982  2008-04-18        T20  Indian Premier League        1
# 4         335982  2008-04-18        T20  Indian Premier League        1
# ...          ...         ...        ...                    ...      ...
# 295727   1535465  2026-05-31        T20  Indian Premier League        2
# 295728   1535465  2026-05-31        T20  Indian Premier League        2
# 295729   1535465  2026-05-31        T20  Indian Premier League        2
# 295730   1535465  2026-05-31        T20  Indian Premier League        2
# 295731   1535465  2026-05-31        T20  Indian Premier League        2
#
#                        batting_team                 bowling_team  over  ball  \
# ...
